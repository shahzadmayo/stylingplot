# %% [markdown]
# # Seaborn | Style And Color
# ## The ways of styling themes are as follows:
#
# ### white
# ### dark
# ### whitegrid
# ### darkgrid
# ### ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load the tips dataset present by default in seaborn
tips = sns.load_dataset('tips')
sns.set_style('white')

# make a countplot
sns.countplot(x ='sex', data = tips)
plt.show()

# %%
# load the tips dataset present by default in seaborn
tips = sns.load_dataset('tips')
sns.set_style('white')

# make a countplot
sns.countplot(x ='sex', data = tips,palette = 'deep')
plt.show()

# %% [markdown]
# # Removing Axes Spines
# ## The despine() is a function that removes the spines from the right and upper portion of the plot by default

# %%
tips = sns.load_dataset('tips')
sns.countplot(x ='sex', data = tips)
sns.despine()

# %% [markdown]
# # Size and aspect
# ### Non grid plot: The figure() is a matplotlib function used to plot the figures. The figsize is used to set the size of the figure.

# %%
tips = sns.load_dataset('tips')
plt.figure(figsize =(6, 6))
sns.countplot(x ='sex', data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Grid type plot

# %%
tips = sns.load_dataset('tips')
sns.lmplot(x ='total_bill', y ='tip', size = 10, aspect = 6, data = tips)
# Out:
# C:\Python310\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Scale and Context
#
# ## The set_context() allows us to override default parameters.
# ## The context are:
#
# ### poster
# ### paper
# ### notebook
# ### talk

# %%
tips = sns.load_dataset('tips')
sns.set_context('poster', font_scale = 2)
sns.countplot(x ='sex', data = tips, palette ='coolwarm')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # Seaborn – Color Palette
# ## We will classify the different ways for using color_palette() types −
#
# ### Qualitative
# ### Sequential
# ### Diverging
# ## Qualitative
# ### A qualitative palette is used when the variable is categorical in nature,

# %%
from matplotlib import pyplot as plt
import seaborn as sns

current_palette = sns.color_palette()
sns.palplot(current_palette)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
current_palette = sns.color_palette()
sns.palplot(sns.color_palette("Greys"))
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sns
current_palette = sns.color_palette()
sns.palplot(sns.color_palette("terrain_r", 7))
plt.show()
